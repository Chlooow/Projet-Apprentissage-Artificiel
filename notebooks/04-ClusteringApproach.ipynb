# %% [markdown]
# # 3) (BONUS) Approach Clustering
#
# Cette approche consiste à premièrement faire du clustering pour y extraire des groupes, puis, y injecter un modèle de regression sur chaque groupe

# %%
# Imports
import sys
import os

from load_data import load_dior

# chargement du dataset
df = load_dior()
